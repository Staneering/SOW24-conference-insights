# %%
import pandas as pd

# %%
sow_data=pd.read_csv('SCHOOL OF WORSHIP 2024.csv')

sow_data.head()
# Out:
#                    Timestamp              Name (Surname first)  Gender  \
# 0  2024/01/21 7:43:08 pm CET         Fagbamila Ajoke Olubukola  Female
# 1  2024/01/21 7:44:21 pm CET                 Jegede Babafunso     Male
# 2  2024/01/21 7:53:16 pm CET          Adekunle Oluwatimileyin     Male
# 3  2024/01/21 7:55:30 pm CET           Ayomide Babalola Isaiah    Male
# 4  2024/01/21 7:56:57 pm CET  ADEMOLU PRECIOUS OLUWATIMILEHIN     Male
#
#   Phone number with Country code e.g +234 xxx for Nigerians  \
# 0                                     +2347032601977
# 1                                     +2347054554848
# 2                                     +2349135473079
# 3                                     +2348181210013
# 4                                     +2348068268106
#
#                               Email  \
# 0            nikkygold183@gmail.com
# 1         Babafunsojegede@gmail.com
# 2  oluwatimileyinadekunle@gmail.com
# 3              ibabalola1@gmail.com
# ...

# %%
sow_data['Location'].value_counts()
# Out:
# Location
# Ibadan                       30
# Oyo                          30
# Ibadan                       23
# Lagos                        17
# Oyo state                    15
#                              ..
# Bénin Republic                1
# Ogun, Nigeria                 1
# Moniya,Ibadan, Oyo State      1
# Rivers state                  1
# RIVERS STATE                  1
# Name: count, Length: 198, dtype: int64

# %%
# Strip "Nigeria" (case-insensitive) from the 'Location' column
sow_data['Location'] = sow_data['Location'].str.replace('nigeria', '', case=False)
# Rename "republic" to "Bene republic" (case-insensitive)
sow_data['Location'] = sow_data['Location'].str.replace('Bénin Republic', 'Bene Republic', case=False)

# Print the updated DataFrame
sow_data.head()
# Out:
#                    Timestamp                              Name  Gender  \
# 0  2024/01/21 7:43:08 pm CET         Fagbamila Ajoke Olubukola  Female
# 1  2024/01/21 7:44:21 pm CET                 Jegede Babafunso     Male
# 2  2024/01/21 7:53:16 pm CET          Adekunle Oluwatimileyin     Male
# 3  2024/01/21 7:55:30 pm CET           Ayomide Babalola Isaiah    Male
# 4  2024/01/21 7:56:57 pm CET  ADEMOLU PRECIOUS OLUWATIMILEHIN     Male
#
#      Phone Number                             Email            Location  \
# 0  +2347032601977            nikkygold183@gmail.com              Ibadan
# 1  +2347054554848         Babafunsojegede@gmail.com               Lagos
# 2  +2349135473079  oluwatimileyinadekunle@gmail.com              Oyo,
# 3  +2348181210013              ibabalola1@gmail.com                 Imo
# 4  +2348068268106         ademoluprecious@gmail.com  Ibadan, Oyo state
#
#           Source
# 0          Other
# 1          Other
# 2          Other
# 3  Word of mouth
# ...

# %%
# Check for "Benin Republic" (case-insensitive)
benin_entries = sow_data[sow_data['Location'].str.contains('republic', case=False)]

# Print the entries containing "Benin Republic"
print(benin_entries)
# Out:
#                      Timestamp                           Name  Gender  \
# 126  2024/01/25 3:37:09 pm CET  Sonoiki Yewande Oreoluwatayo   Female
#
#      Phone Number                      Email         Location         Source
# 126  +22958926377  sonoikioreoluwa@gmail.com  Bénin Republic   Word of mouth

# %%
female_participants = sow_data[sow_data['Gender']=='Female']

female_participants.head()
# Out:
#                     Timestamp         Name (Surname first)  Gender  \
# 0   2024/01/21 7:43:08 pm CET    Fagbamila Ajoke Olubukola  Female
# 6   2024/01/21 8:06:25 pm CET            Ojo Eniola Esther  Female
# 7   2024/01/21 8:08:45 pm CET  AJELEKE MARY OLUWASUNMISOLA  Female
# 8   2024/01/21 8:17:22 pm CET      Albert ifeoluwa emerald  Female
# 13  2024/01/21 8:40:56 pm CET                 Waheed Orire  Female
#
#    Phone number with Country code e.g +234 xxx for Nigerians  \
# 0                                      +2347032601977
# 6                                      +2348167480247
# 7                                     +234 9033214123
# 8                                      +2349068483900
# 13                                        08029900305
#
#                         Email  \
# 0      nikkygold183@gmail.com
# 6   ojoeniolaesther@gmail.com
# 7       ajelekemary@gmail.com
# 8   emeraldalbert09@gmail.com
# 13      mojisolaf27@gmail.com
#
# ...

# %%
female_participants.to_csv('SOW24_female_participants.csv', index=False)

# %%
sow_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421 entries, 0 to 420
# Data columns (total 7 columns):
#  #   Column                                                                     Non-Null Count  Dtype
# ---  ------                                                                     --------------  -----
#  0   Timestamp                                                                  421 non-null    object
#  1   Name (Surname first)                                                       421 non-null    object
#  2   Gender                                                                     421 non-null    object
#  3   Phone number with Country code e.g +234 xxx for Nigerians                  421 non-null    object
#  4   Email                                                                      421 non-null    object
#  5   Your location
# ( for those from Nigeria, include your  state of residence)  421 non-null    object
# ...

# %%
sow_data.rename(columns={location:'Location'}, inplace=True)

sow_data.head()
# Out:
#                    Timestamp              Name (Surname first)  Gender  \
# 0  2024/01/21 7:43:08 pm CET         Fagbamila Ajoke Olubukola  Female
# 1  2024/01/21 7:44:21 pm CET                 Jegede Babafunso     Male
# 2  2024/01/21 7:53:16 pm CET          Adekunle Oluwatimileyin     Male
# 3  2024/01/21 7:55:30 pm CET           Ayomide Babalola Isaiah    Male
# 4  2024/01/21 7:56:57 pm CET  ADEMOLU PRECIOUS OLUWATIMILEHIN     Male
#
#   Phone number with Country code e.g +234 xxx for Nigerians  \
# 0                                     +2347032601977
# 1                                     +2347054554848
# 2                                     +2349135473079
# 3                                     +2348181210013
# 4                                     +2348068268106
#
#                               Email  \
# 0            nikkygold183@gmail.com
# 1         Babafunsojegede@gmail.com
# 2  oluwatimileyinadekunle@gmail.com
# 3              ibabalola1@gmail.com
# ...

# %%
sow_data['Gender'].value_counts()
# Out:
# Gender
# Female    244
# Male      177
# Name: count, dtype: int64

# %%
location = sow_data.columns[5]
print(location
      )
phone_number = sow_data.columns[3]
name = sow_data.columns[1]
source=sow_data.columns[-1]
# Out:
# Your location
# ( for those from Nigeria, include your  state of residence)

# %%
sow_data.rename(columns={location:'Location', phone_number:'Phone Number', name:'Name', source:'Source'}, inplace=True)

sow_data.head()
# Out:
#                    Timestamp                              Name  Gender  \
# 0  2024/01/21 7:43:08 pm CET         Fagbamila Ajoke Olubukola  Female
# 1  2024/01/21 7:44:21 pm CET                 Jegede Babafunso     Male
# 2  2024/01/21 7:53:16 pm CET          Adekunle Oluwatimileyin     Male
# 3  2024/01/21 7:55:30 pm CET           Ayomide Babalola Isaiah    Male
# 4  2024/01/21 7:56:57 pm CET  ADEMOLU PRECIOUS OLUWATIMILEHIN     Male
#
#      Phone Number                             Email            Location  \
# 0  +2347032601977            nikkygold183@gmail.com              Ibadan
# 1  +2347054554848         Babafunsojegede@gmail.com               Lagos
# 2  +2349135473079  oluwatimileyinadekunle@gmail.com       Oyo, Nigeria
# 3  +2348181210013              ibabalola1@gmail.com                 Imo
# 4  +2348068268106         ademoluprecious@gmail.com  Ibadan, Oyo state
#
#           Source
# 0          Other
# 1          Other
# 2          Other
# 3  Word of mouth
# ...

# %%
# @title Gender

from matplotlib import pyplot as plt
import seaborn as sns
sow_data.groupby('Gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Source

from matplotlib import pyplot as plt
import seaborn as sns
sow_data.groupby('Source').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
sow_data['Location'].value_counts()
# Out:
# Location
# Ibadan                       30
# Oyo                          30
# Ibadan                       23
# Lagos                        17
# Oyo state                    15
#                              ..
# Bénin Republic                1
# Ogun, Nigeria                 1
# Moniya,Ibadan, Oyo State      1
# Rivers state                  1
# RIVERS STATE                  1
# Name: count, Length: 198, dtype: int64

# %%
sow_data.groupby('Gender')['Location']

# %%
nigerian_states = [
    "Abia", "Adamawa", "Akwa Ibom", "Anambra", "Bauchi", "Bayelsa", "Benue", "Borno",
    "Cross River", "Delta", "Ebonyi", "Edo", "Ekiti", "Enugu", "FCT", "Gombe", "Imo",
    "Jigawa", "Kaduna", "Kano", "Katsina", "Kebbi", "Kogi", "Kwara", "Lagos", "Nasarawa",
    "Niger", "Ogun", "Ondo", "Osun", "Oyo", "Plateau", "Rivers", "Sokoto", "Taraba", "Yobe", "Zamfara"
]

# Corresponding capitals
capitals = [
    "Umuahia", "Yola", "Uyo", "Awka", "Bauchi", "Yenagoa", "Makurdi", "Maiduguri",
    "Calabar", "Asaba", "Abakaliki", "Benin City", "Ado Ekiti", "Enugu", "Abuja", "Gombe", "Owerri",
    "Dutse", "Kaduna", "Kano", "Katsina", "Birnin Kebbi", "Lokoja", "Ilorin", "Ikeja", "Lafia",
    "Minna", "Abeokuta", "Akure", "Oshogbo", "Ibadan", "Jos", "Port Harcourt", "Sokoto", "Jalingo", "Damaturu", "Gusau"
]

# Create a list of lists
state_capitals = list(zip(nigerian_states, capitals))

print(state_capitals)
# Out:
# [('Abia', 'Umuahia'), ('Adamawa', 'Yola'), ('Akwa Ibom', 'Uyo'), ('Anambra', 'Awka'), ('Bauchi', 'Bauchi'), ('Bayelsa', 'Yenagoa'), ('Benue', 'Makurdi'), ('Borno', 'Maiduguri'), ('Cross River', 'Calabar'), ('Delta', 'Asaba'), ('Ebonyi', 'Abakaliki'), ('Edo', 'Benin City'), ('Ekiti', 'Ado Ekiti'), ('Enugu', 'Enugu'), ('FCT', 'Abuja'), ('Gombe', 'Gombe'), ('Imo', 'Owerri'), ('Jigawa', 'Dutse'), ('Kaduna', 'Kaduna'), ('Kano', 'Kano'), ('Katsina', 'Katsina'), ('Kebbi', 'Birnin Kebbi'), ('Kogi', 'Lokoja'), ('Kwara', 'Ilorin'), ('Lagos', 'Ikeja'), ('Nasarawa', 'Lafia'), ('Niger', 'Minna'), ('Ogun', 'Abeokuta'), ('Ondo', 'Akure'), ('Osun', 'Oshogbo'), ('Oyo', 'Ibadan'), ('Plateau', 'Jos'), ('Rivers', 'Port Harcourt'), ('Sokoto', 'Sokoto'), ('Taraba', 'Jalingo'), ('Yobe', 'Damaturu'), ('Zamfara', 'Gusau')]

# %%
# Using a list comprehension to create a new list with lowercase strings
lowercase_state_capitals = [
    (state.lower(), capital.lower()) for state, capital in state_capitals
]

print(lowercase_state_capitals)
# Out:
# [('abia', 'umuahia'), ('adamawa', 'yola'), ('akwa ibom', 'uyo'), ('anambra', 'awka'), ('bauchi', 'bauchi'), ('bayelsa', 'yenagoa'), ('benue', 'makurdi'), ('borno', 'maiduguri'), ('cross river', 'calabar'), ('delta', 'asaba'), ('ebonyi', 'abakaliki'), ('edo', 'benin city'), ('ekiti', 'ado ekiti'), ('enugu', 'enugu'), ('fct', 'abuja'), ('gombe', 'gombe'), ('imo', 'owerri'), ('jigawa', 'dutse'), ('kaduna', 'kaduna'), ('kano', 'kano'), ('katsina', 'katsina'), ('kebbi', 'birnin kebbi'), ('kogi', 'lokoja'), ('kwara', 'ilorin'), ('lagos', 'ikeja'), ('nasarawa', 'lafia'), ('niger', 'minna'), ('ogun', 'abeokuta'), ('ondo', 'akure'), ('osun', 'oshogbo'), ('oyo', 'ibadan'), ('plateau', 'jos'), ('rivers', 'port harcourt'), ('sokoto', 'sokoto'), ('taraba', 'jalingo'), ('yobe', 'damaturu'), ('zamfara', 'gusau')]

# %%
for state,capital in state_capitals:
  state = state.lower()
  capital = capital.lower()

# %%
for location in sow_data['Location']:

  for state,capital in state_capitals:
    if state.lower() in location.lower():
      print(state)
      location = state
      break

sow_data['Location'].value_counts()
# Out:
# Lagos
# Niger
# Imo
# Oyo
# Oyo
# Lagos
# Bayelsa
# Niger
# Oyo
# Lagos
# Niger
# Oyo
# Enugu
# Niger
# Oyo
# Oyo
# Oyo
# Oyo
# Niger
# Lagos
# Oyo
# Kebbi
# Oyo
# Niger
# Lagos
# Niger
# Rivers
# Oyo
# Oyo
# Lagos
# Oyo
# Oyo
# Oyo
# Akwa Ibom
# Kwara
# Oyo
# Oyo
# Oyo
# Oyo
# Niger
# Oyo
# Oyo
# Rivers
# Niger
# Niger
# Niger
# Oyo
# Niger
# Niger
# Ogun
# Niger
# Oyo
# Delta
# Oyo
# Niger
# Niger
# Oyo
# Lagos
# Oyo
# Niger
# Oyo
# Oyo
# Oyo
# Oyo
# Oyo
# Oyo
# Oyo
# Ogun
# Niger
# Niger
# Oyo
# Oyo
# Oyo
# Oyo
# Oyo
# Oyo
# Oyo
# Oyo
# Niger
# Oyo
# Oyo
# Rivers
# Edo
# Oyo
# Lagos
# Edo
# Oyo
# Oyo
# Oyo
# Oyo
# Lagos
# Oyo
# Lagos
# Oyo
# Lagos
# Niger
# Oyo
# Niger
# Niger
# Lagos
# Niger
# Oyo
# Oyo
# Rivers
# Niger
# Oyo
# Bayelsa
# Oyo
# Oyo
# Oyo
# Oyo
# Niger
# Oyo
# Oyo
# Oyo
# Oyo
# Oyo
# Lagos
# Oyo
# Oyo
# Oyo
# Oyo
# Oyo
# Lagos
# Niger
# Lagos
# Niger
# Niger
# Oyo
# Ogun
# Ogun
# Oyo
# Lagos
# Lagos
# Niger
# Oyo
# Lagos
# Ekiti
# Oyo
# Niger
# Enugu
# Lagos
# ...

# %%
# Convert all locations and states to lowercase for case-insensitive comparison
lower_states = [state.lower() for state, _ in state_capitals]
lower_capitals = [capital.lower() for _, capital in state_capitals]

# Iterate and update locations
for i in range(len(sow_data)):
    location = sow_data.loc[i, 'Location'].lower()
    for state,capital in lowercase_state_capitals:
        if (state in location) or (capital in location):
            sow_data.loc[i, 'Location'] = state.upper()
            break  # Move to the next location once a match is found

# %%
sow_data['Location'].value_counts()
# Out:
# Location
# OYO                                          242
# LAGOS                                         62
# NIGER                                         52
# OGUN                                          16
# EDO                                            6
# RIVERS                                         6
# BAYELSA                                        4
# CROSS RIVER                                    3
# KWARA                                          2
# ABIA                                           2
# OSUN                                           2
# ONDO                                           2
# ENUGU                                          2
# IMO                                            2
# Egbeda                                         1
# England                                        1
# praiseabimbola57@gmail.com                     1
# https://maps.app.goo.gl/LJtxSU9fGvMUMgjR8      1
# Bodija                                         1
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# Standardize locations
lower_states = [state.lower() for state, _ in state_capitals]
sow_data['Location'] = sow_data['Location'].apply(lambda x: next((state for state in lower_states if state in x.lower()), 'Unknown'))

# Generate a list of random colors
num_states = len(state_counts)
colors = [plt.cm.get_cmap('viridis')(random.random()) for _ in range(num_states)]


# Count state occurrences
state_counts = sow_data['Location'].value_counts()

# Create bar chart
plt.figure(figsize=(12, 6))  # Adjust figure size as needed
state_counts.plot(kind='bar',color=colors)
plt.xlabel('State')
plt.ylabel('Count')
plt.title('Distribution of States in Location Column')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.tight_layout()  # Adjust layout for better spacing
plt.show()
# Out:
# <ipython-input-65-cc1f65577fa9>:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = [plt.cm.get_cmap('viridis')(random.random()) for _ in range(num_states)]

# %%
sow_data.head()
# Out:
#                    Timestamp                              Name  Gender  \
# 0  2024/01/21 7:43:08 pm CET         Fagbamila Ajoke Olubukola  Female
# 1  2024/01/21 7:44:21 pm CET                 Jegede Babafunso     Male
# 2  2024/01/21 7:53:16 pm CET          Adekunle Oluwatimileyin     Male
# 3  2024/01/21 7:55:30 pm CET           Ayomide Babalola Isaiah    Male
# 4  2024/01/21 7:56:57 pm CET  ADEMOLU PRECIOUS OLUWATIMILEHIN     Male
#
#      Phone Number                             Email Location         Source
# 0  +2347032601977            nikkygold183@gmail.com      oyo          Other
# 1  +2347054554848         Babafunsojegede@gmail.com    lagos          Other
# 2  +2349135473079  oluwatimileyinadekunle@gmail.com    niger          Other
# 3  +2348181210013              ibabalola1@gmail.com      imo  Word of mouth
# 4  +2348068268106         ademoluprecious@gmail.com      oyo  Word of mouth

# %%
import matplotlib.pyplot as plt

# Filter for rows where 'Source' is "word of mouth" (case-insensitive)
word_of_mouth_locations = sow_data[sow_data['Source'].str.lower() == 'word of mouth']['Location']

# Print the locations
print(word_of_mouth_locations)

# Count location occurrences
location_counts = word_of_mouth_locations.value_counts()

# Create bar chart
plt.figure(figsize=(12, 6))  # Adjust figure size as needed
location_counts.plot(kind='bar')
plt.xlabel('Location')
plt.ylabel('Count')
plt.title('Distribution of Locations from Word of Mouth')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.tight_layout()  # Adjust layout for better spacing
plt.show()
# Out:
# 3          imo
# 4          oyo
# 5          oyo
# 7      bayelsa
# 15         oyo
#         ...
# 414        oyo
# 415     rivers
# 416        oyo
# 418        oyo
# 420        oyo
# Name: Location, Length: 169, dtype: object

# %%
import matplotlib.pyplot as plt

# Group data by location and source, then count occurrences
location_source_counts = sow_data.groupby(['Location', 'Source'])['Source'].count().unstack()

# Create grouped bar chart
location_source_counts.plot(kind='bar', figsize=(12, 6))
plt.xlabel('Location')
plt.ylabel('Count')
plt.title('Distribution of Sources by Location')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Source')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Filter for rows where 'Source' is "word of mouth" (case-insensitive)
word_of_mouth_data = sow_data[sow_data['Source'].str.lower() == 'word of mouth']

# Count location occurrences for "word of mouth"
location_counts = word_of_mouth_data['Location'].value_counts()
# Generate a list of random colors
num_states = len(location_counts)
colors = [plt.cm.get_cmap('viridis')(random.random()) for _ in range(num_states)]

# Create bar chart
plt.figure(figsize=(12, 6))
location_counts.plot(kind='bar',color = colors)
plt.xlabel('Location')
plt.ylabel('Count')
plt.title('Distribution of Locations for Word of Mouth')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-74-c4f58b0e9644>:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = [plt.cm.get_cmap('viridis')(random.random()) for _ in range(num_states)]

# %%
import matplotlib.pyplot as plt

# Filter for rows where 'Source' is "word of mouth" (case-insensitive)
word_of_mouth_data = sow_data[sow_data['Source'].str.lower() == 'word of mouth']

# Count location occurrences for "word of mouth"
location_counts = word_of_mouth_data['Location'].value_counts()

# Create bar chart
plt.figure(figsize=(12, 6))
location_counts.plot(kind='bar')
plt.xlabel('Location')
plt.ylabel('Count')
plt.title('Distribution of Locations for Word of Mouth')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Filter for rows where 'Location' is "Unknown"
unknown_location_data = sow_data[sow_data['Location'] == 'Unknown']

# Count source occurrences for "Unknown" location
source_counts = unknown_location_data['Source'].value_counts()
# Generate a list of random colors
num_states = len(source_counts)
colors = [plt.cm.get_cmap('viridis')(random.random()) for _ in range(num_states)]

# Create bar chart
plt.figure(figsize=(10, 6))
source_counts.plot(kind='bar',color = colors)
plt.xlabel('Source')
plt.ylabel('Count')
plt.title('Distribution of Sources for Unknown Location')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-71-9b371a228539>:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = [plt.cm.get_cmap('viridis')(random.random()) for _ in range(num_states)]
